# %%
import pandas as pd

# %%
df = pd.read_csv('World_Development_Indicators/Data.csv')

# %%
df.head()
# Out:
#                                 Series Name        Series Code  \
# 0  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 3  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 4  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#      Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0     Afghanistan          AFG        21.177        22.078        23.737
# 1         Albania          ALB        36.428        41.741        52.163
# 2         Algeria          DZA        52.085        59.919         67.54
# 3  American Samoa          ASM        80.948        88.587        87.594
# 4         Andorra          AND        94.712        92.395        88.819
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series Name    266 non-null    object
#  1   Series Code    264 non-null    object
#  2   Country Name   264 non-null    object
#  3   Country Code   264 non-null    object
#  4   1990 [YR1990]  264 non-null    object
#  5   2000 [YR2000]  264 non-null    object
#  6   2010 [YR2010]  264 non-null    object
#  7   2011 [YR2011]  264 non-null    object
#  8   2012 [YR2012]  264 non-null    object
#  9   2013 [YR2013]  264 non-null    object
#  10  2014 [YR2014]  264 non-null    object
#  11  2015 [YR2015]  264 non-null    object
#  12  2016 [YR2016]  264 non-null    object
#  13  2017 [YR2017]  264 non-null    object
#  14  2018 [YR2018]  264 non-null    object
#  15  2019 [YR2019]  264 non-null    object
# dtypes: object(16)
# memory usage: 33.8+ KB

# %%
df.iloc[10:20, :]
# Out:
#                                  Series Name        Series Code  Country Name  \
# 10  Urban population (% of total population)  SP.URB.TOTL.IN.ZS     Australia
# 11  Urban population (% of total population)  SP.URB.TOTL.IN.ZS       Austria
# 12  Urban population (% of total population)  SP.URB.TOTL.IN.ZS    Azerbaijan
# 13  Urban population (% of total population)  SP.URB.TOTL.IN.ZS  Bahamas, The
# 14  Urban population (% of total population)  SP.URB.TOTL.IN.ZS       Bahrain
# 15  Urban population (% of total population)  SP.URB.TOTL.IN.ZS    Bangladesh
# 16  Urban population (% of total population)  SP.URB.TOTL.IN.ZS      Barbados
# 17  Urban population (% of total population)  SP.URB.TOTL.IN.ZS       Belarus
# 18  Urban population (% of total population)  SP.URB.TOTL.IN.ZS       Belgium
# 19  Urban population (% of total population)  SP.URB.TOTL.IN.ZS        Belize
#
#    Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011]  \
# ...

# %%
df.iloc[:5]
# Out:
#                                 Series Name        Series Code  \
# 0  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 3  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 4  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#      Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0     Afghanistan          AFG        21.177        22.078        23.737
# 1         Albania          ALB        36.428        41.741        52.163
# 2         Algeria          DZA        52.085        59.919         67.54
# 3  American Samoa          ASM        80.948        88.587        87.594
# 4         Andorra          AND        94.712        92.395        88.819
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...
