# %%
import pandas as pd

# %%
df = pd.read_json('Misc_Data/weather_in_austin.json')

# %%
df
# Out:
#      Temperature (deg F)  Dew Point (deg F)  Pressure (atm)
# 0                   79.0               70.8               1
# 1                   77.4               71.2               1
# 2                   76.4               71.3               1
# 3                   75.7               71.4               1
# 4                   75.1               71.4               1
# ..                   ...                ...             ...
# 739                 86.6               67.2               1
# 740                 83.4               67.8               1
# 741                 81.2               68.4               1
# 742                 79.7               68.9               1
# 743                 78.2               69.2               1
#
# [744 rows x 3 columns]

# %%
plt = df.plot(figsize=(20,6))

# %%
plt = df.plot(subplots=True, figsize=(20,6))

# %%
df['Dew Point (deg F)'].plot(figsize=(20,6))

# %%
column_list2 = ['Temperature (deg F)','Dew Point (deg F)']
plt = df[column_list2].plot(figsize=(20,6))
